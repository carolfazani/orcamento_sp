# %% [markdown]
# <a href="https://colab.research.google.com/github/carolfazani/orcamento_sp/blob/main/plt_style_use.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Os 26 estilos pré-definidos do Matplolib

# %% [markdown]
# plt.style.use()
#
# [‘Solarize_Light2’, ‘_classic_test_patch’, ‘bmh’, ‘classic’, ‘dark_background’, ‘fast’, ‘fivethirtyeight’, ‘ggplot’,’grayscale’,’seaborn’,’seaborn-bright’,’seaborn-colorblind’, ‘seaborn-dark’, ‘seaborn-dark-palette’, ‘seaborn-darkgrid’, ‘seaborn-deep’, ‘seaborn-muted’, ‘seaborn-notebook’, ‘seaborn-paper’, ‘seaborn-pastel’, ‘seaborn-poster’,’seaborn-talk’,’seaborn-ticks’,’seaborn-white’,’seaborn-whitegrid’,’tableau-colorblind10′]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_av = pd.read_csv('/content/df_av.csv', index_col='Unnamed: 0')

# %%
df_av
# Out:
#       RECEITA TRIBUTÁRIA  TRANSFERÊNCIAS CORRENTES  SUPERAVIT FINANCEIRO  \
# 2017               49.31                     27.28                  0.32
# 2018               54.70                     27.93                  0.24
# 2019               53.91                     26.07                  2.97
# 2020               53.03                     28.34                  3.11
# 2021               57.10                     26.54                  8.55
#
#       RECEITA DE CONTRIBUIÇÕES  OUTRAS RECEITAS DE CAPITAL  \
# 2017                      7.25                        0.68
# 2018                      7.26                        1.89
# 2019                      7.94                        4.90
# 2020                      7.76                        2.13
# 2021                      6.72                        3.47
#
#       OUTRAS RECEITAS CORRENTES  RECEITA PATRIMONIAL  \
# 2017                      11.10                 1.91
# 2018                       4.65                 1.42
# 2019                       3.34                 1.94
# 2020                       2.33                 3.73
# 2021                       2.37                 2.24
#
#       TRANSFERÊNCIAS DE CAPITAL  RECEITA DE SERVIÇOS  OPERAÇÕES DE CRÉDITO
# 2017                       1.24                 1.06                  0.09
# 2018                       1.31                 0.47                  0.27
# 2019                       0.96                 0.40                  0.46
# 2020                       1.13                 0.68                  0.77
# 2021                       0.86                 0.38                  0.16

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('Solarize_Light2')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('_classic_test_patch')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('bmh')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('classic')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('dark_background')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('fast')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('fivethirtyeight')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('ggplot')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('grayscale')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-bright')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-colorblind')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-dark')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-dark-palette')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-darkgrid')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-deep')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-muted')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-notebook')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-paper')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-pastel')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-poster')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-talk')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-ticks')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-white')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('seaborn-whitegrid')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')

# %%
df_av.plot(kind="barh",stacked=True, width=0.9, figsize=(12,10))
plt.style.use('tableau-colorblind10')
plt.xlim(0, 100)
plt.xticks(fontsize=15)


#coloca o sinal %
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels([f'{x.astype(int)}%' for x in current_values])

#coloca a legenda fora dp gráfico
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
plt.savefig('grafico8.png', transparent= True, bbox_inches='tight')
